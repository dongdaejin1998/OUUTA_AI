# %%
import import_ipynb
from nlp_main_final import predict_sentence
from vision_main_final import predict_video
import numpy as np
# Out:
# importing Jupyter notebook from nlp_main_final.ipynb
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# Requirement already satisfied: import_ipynb in c:\users\user\anaconda3\envs\ml\lib\site-packages (0.1.4)
# Requirement already satisfied: nbformat in c:\users\user\anaconda3\envs\ml\lib\site-packages (from import_ipynb) (5.3.0)
# Requirement already satisfied: IPython in c:\users\user\anaconda3\envs\ml\lib\site-packages (from import_ipynb) (8.4.0)
# Requirement already satisfied: decorator in c:\users\user\anaconda3\envs\ml\lib\site-packages (from IPython->import_ipynb) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from IPython->import_ipynb) (3.0.20)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\envs\ml\lib\site-packages (from IPython->import_ipynb) (0.4.5)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from IPython->import_ipynb) (2.11.2)
# Requirement already satisfied: traitlets>=5 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from IPython->import_ipynb) (5.1.1)
# Requirement already satisfied: pickleshare in c:\users\user\anaconda3\envs\ml\lib\site-packages (from IPython->import_ipynb) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from IPython->import_ipynb) (0.18.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from IPython->import_ipynb) (61.2.0)
# Requirement already satisfied: backcall in c:\users\user\anaconda3\envs\ml\lib\site-packages (from IPython->import_ipynb) (0.2.0)
# Requirement already satisfied: matplotlib-inline in c:\users\user\anaconda3\envs\ml\lib\site-packages (from IPython->import_ipynb) (0.1.2)
# Requirement already satisfied: stack-data in c:\users\user\anaconda3\envs\ml\lib\site-packages (from IPython->import_ipynb) (0.2.0)
# Requirement already satisfied: jupyter-core in c:\users\user\anaconda3\envs\ml\lib\site-packages (from nbformat->import_ipynb) (4.10.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from nbformat->import_ipynb) (4.4.0)
# Requirement already satisfied: fastjsonschema in c:\users\user\anaconda3\envs\ml\lib\site-packages (from nbformat->import_ipynb) (2.15.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from jedi>=0.16->IPython->import_ipynb) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from jsonschema>=2.6->nbformat->import_ipynb) (0.18.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from jsonschema>=2.6->nbformat->import_ipynb) (5.2.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from jsonschema>=2.6->nbformat->import_ipynb) (21.4.0)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\envs\ml\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->import_ipynb) (0.2.5)
# Requirement already satisfied: pywin32>=1.0 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from jupyter-core->nbformat->import_ipynb) (302)
# Requirement already satisfied: pure-eval in c:\users\user\anaconda3\envs\ml\lib\site-packages (from stack-data->IPython->import_ipynb) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\user\anaconda3\envs\ml\lib\site-packages (from stack-data->IPython->import_ipynb) (2.0.5)
# Requirement already satisfied: executing in c:\users\user\anaconda3\envs\ml\lib\site-packages (from stack-data->IPython->import_ipynb) (0.8.3)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->import_ipynb) (3.8.0)
# Requirement already satisfied: six in c:\users\user\anaconda3\envs\ml\lib\site-packages (from asttokens->stack-data->IPython->import_ipynb) (1.16.0)
# importing Jupyter notebook from nlp_Preproc_final.ipynb
# Requirement already satisfied: mxnet in c:\users\user\anaconda3\envs\ml\lib\site-packages (1.7.0.post2)
# Requirement already satisfied: requests<2.19.0,>=2.18.4 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from mxnet) (2.18.4)
# Requirement already satisfied: graphviz<0.9.0,>=0.8.1 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from mxnet) (0.8.4)
# Collecting numpy<1.17.0,>=1.8.2
#   Using cached numpy-1.16.6-cp38-cp38-win_amd64.whl
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from requests<2.19.0,>=2.18.4->mxnet) (1.22)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from requests<2.19.0,>=2.18.4->mxnet) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from requests<2.19.0,>=2.18.4->mxnet) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from requests<2.19.0,>=2.18.4->mxnet) (2022.6.15)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.4
#     Uninstalling numpy-1.23.4:
#       Successfully uninstalled numpy-1.23.4
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
#     WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
#     WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
#     WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
#     WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 5] 액세스가 거부되었습니다: 'C:\\Users\\user\\anaconda3\\envs\\ml\\Lib\\site-packages\\numpy\\~%4bs\\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# Requirement already satisfied: gluonnlp in c:\users\user\anaconda3\envs\ml\lib\site-packages (0.10.0)
# Requirement already satisfied: pandas in c:\users\user\anaconda3\envs\ml\lib\site-packages (1.4.3)
# Requirement already satisfied: tqdm in c:\users\user\anaconda3\envs\ml\lib\site-packages (4.64.0)
# Requirement already satisfied: packaging in c:\users\user\anaconda3\envs\ml\lib\site-packages (from gluonnlp) (21.3)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from gluonnlp) (1.16.6)
# Requirement already satisfied: cython in c:\users\user\anaconda3\envs\ml\lib\site-packages (from gluonnlp) (0.29.32)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from pandas) (2022.1)
# Collecting numpy>=1.16.0
#   Downloading numpy-1.23.5-cp38-cp38-win_amd64.whl (14.7 MB)
#      --------------------------------------- 14.7/14.7 MB 10.9 MB/s eta 0:00:00
# Requirement already satisfied: colorama in c:\users\user\anaconda3\envs\ml\lib\site-packages (from tqdm) (0.4.5)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from packaging->gluonnlp) (3.0.4)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.16.6
#     Uninstalling numpy-1.16.6:
#       Successfully uninstalled numpy-1.16.6
# Successfully installed numpy-1.23.5
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
#     WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
#     WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
#     WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
#     WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.9.1 requires tensorboard<2.10,>=2.9, but you have tensorboard 2.10.0 which is incompatible.
# tensorboard 2.10.0 requires requests<3,>=2.21.0, but you have requests 2.18.4 which is incompatible.
# scipy 1.7.3 requires numpy<1.23.0,>=1.16.5, but you have numpy 1.23.5 which is incompatible.
# numba 0.55.1 requires numpy<1.22,>=1.18, but you have numpy 1.23.5 which is incompatible.
# mxnet 1.7.0.post2 requires numpy<1.17.0,>=1.8.2, but you have numpy 1.23.5 which is incompatible.
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# Requirement already satisfied: sentencepiece in c:\users\user\anaconda3\envs\ml\lib\site-packages (0.1.97)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# Requirement already satisfied: transformers==3.0.2 in c:\users\user\anaconda3\envs\ml\lib\site-packages (3.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from transformers==3.0.2) (2022.7.25)
# Requirement already satisfied: sacremoses in c:\users\user\anaconda3\envs\ml\lib\site-packages (from transformers==3.0.2) (0.0.53)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\envs\ml\lib\site-packages (from transformers==3.0.2) (1.23.5)
# Requirement already satisfied: tokenizers==0.8.1.rc1 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from transformers==3.0.2) (0.8.1rc1)
# Requirement already satisfied: sentencepiece!=0.1.92 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from transformers==3.0.2) (0.1.97)
# Requirement already satisfied: packaging in c:\users\user\anaconda3\envs\ml\lib\site-packages (from transformers==3.0.2) (21.3)
# Requirement already satisfied: tqdm>=4.27 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from transformers==3.0.2) (4.64.0)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\envs\ml\lib\site-packages (from transformers==3.0.2) (3.8.0)
# Requirement already satisfied: requests in c:\users\user\anaconda3\envs\ml\lib\site-packages (from transformers==3.0.2) (2.18.4)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\envs\ml\lib\site-packages (from tqdm>=4.27->transformers==3.0.2) (0.4.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from packaging->transformers==3.0.2) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from requests->transformers==3.0.2) (2022.6.15)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from requests->transformers==3.0.2) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from requests->transformers==3.0.2) (1.22)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from requests->transformers==3.0.2) (2.6)
# Requirement already satisfied: joblib in c:\users\user\anaconda3\envs\ml\lib\site-packages (from sacremoses->transformers==3.0.2) (1.1.0)
# Requirement already satisfied: click in c:\users\user\anaconda3\envs\ml\lib\site-packages (from sacremoses->transformers==3.0.2) (8.0.4)
# Requirement already satisfied: six in c:\users\user\anaconda3\envs\ml\lib\site-packages (from sacremoses->transformers==3.0.2) (1.16.0)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# Requirement already satisfied: torch in c:\users\user\anaconda3\envs\ml\lib\site-packages (1.12.1)
# Requirement already satisfied: typing_extensions in c:\users\user\anaconda3\envs\ml\lib\site-packages (from torch) (4.3.0)
# C:\Users\user\anaconda3\envs\ml\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# 2.9.1
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# importing Jupyter notebook from nlp_model_final.ipynb
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# Requirement already satisfied: transformers==3.0.2 in c:\users\user\anaconda3\envs\ml\lib\site-packages (3.0.2)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\envs\ml\lib\site-packages (from transformers==3.0.2) (3.8.0)
# Requirement already satisfied: sacremoses in c:\users\user\anaconda3\envs\ml\lib\site-packages (from transformers==3.0.2) (0.0.53)
# Requirement already satisfied: tokenizers==0.8.1.rc1 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from transformers==3.0.2) (0.8.1rc1)
# Requirement already satisfied: tqdm>=4.27 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from transformers==3.0.2) (4.64.0)
# Requirement already satisfied: sentencepiece!=0.1.92 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from transformers==3.0.2) (0.1.97)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from transformers==3.0.2) (2022.7.25)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\envs\ml\lib\site-packages (from transformers==3.0.2) (1.23.5)
# Requirement already satisfied: packaging in c:\users\user\anaconda3\envs\ml\lib\site-packages (from transformers==3.0.2) (21.3)
# Requirement already satisfied: requests in c:\users\user\anaconda3\envs\ml\lib\site-packages (from transformers==3.0.2) (2.18.4)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\envs\ml\lib\site-packages (from tqdm>=4.27->transformers==3.0.2) (0.4.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from packaging->transformers==3.0.2) (3.0.4)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from requests->transformers==3.0.2) (1.22)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from requests->transformers==3.0.2) (2022.6.15)
# Requirement already satisfied: idna<2.7,>=2.5 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from requests->transformers==3.0.2) (2.6)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from requests->transformers==3.0.2) (3.0.4)
# Requirement already satisfied: six in c:\users\user\anaconda3\envs\ml\lib\site-packages (from sacremoses->transformers==3.0.2) (1.16.0)
# Requirement already satisfied: joblib in c:\users\user\anaconda3\envs\ml\lib\site-packages (from sacremoses->transformers==3.0.2) (1.1.0)
# Requirement already satisfied: click in c:\users\user\anaconda3\envs\ml\lib\site-packages (from sacremoses->transformers==3.0.2) (8.0.4)
# Requirement already satisfied: import_ipynb in c:\users\user\anaconda3\envs\ml\lib\site-packages (0.1.4)
# Requirement already satisfied: nbformat in c:\users\user\anaconda3\envs\ml\lib\site-packages (from import_ipynb) (5.3.0)
# Requirement already satisfied: IPython in c:\users\user\anaconda3\envs\ml\lib\site-packages (from import_ipynb) (8.4.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from IPython->import_ipynb) (0.18.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from IPython->import_ipynb) (3.0.20)
# Requirement already satisfied: decorator in c:\users\user\anaconda3\envs\ml\lib\site-packages (from IPython->import_ipynb) (5.1.1)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\envs\ml\lib\site-packages (from IPython->import_ipynb) (0.4.5)
# Requirement already satisfied: stack-data in c:\users\user\anaconda3\envs\ml\lib\site-packages (from IPython->import_ipynb) (0.2.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from IPython->import_ipynb) (2.11.2)
# Requirement already satisfied: traitlets>=5 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from IPython->import_ipynb) (5.1.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from IPython->import_ipynb) (61.2.0)
# Requirement already satisfied: backcall in c:\users\user\anaconda3\envs\ml\lib\site-packages (from IPython->import_ipynb) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\user\anaconda3\envs\ml\lib\site-packages (from IPython->import_ipynb) (0.7.5)
# Requirement already satisfied: matplotlib-inline in c:\users\user\anaconda3\envs\ml\lib\site-packages (from IPython->import_ipynb) (0.1.2)
# Requirement already satisfied: jupyter-core in c:\users\user\anaconda3\envs\ml\lib\site-packages (from nbformat->import_ipynb) (4.10.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from nbformat->import_ipynb) (4.4.0)
# Requirement already satisfied: fastjsonschema in c:\users\user\anaconda3\envs\ml\lib\site-packages (from nbformat->import_ipynb) (2.15.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from jedi>=0.16->IPython->import_ipynb) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from jsonschema>=2.6->nbformat->import_ipynb) (21.4.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from jsonschema>=2.6->nbformat->import_ipynb) (5.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from jsonschema>=2.6->nbformat->import_ipynb) (0.18.0)
# Requirement already satisfied: wcwidth in c:\users\user\anaconda3\envs\ml\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->import_ipynb) (0.2.5)
# Requirement already satisfied: pywin32>=1.0 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from jupyter-core->nbformat->import_ipynb) (302)
# Requirement already satisfied: executing in c:\users\user\anaconda3\envs\ml\lib\site-packages (from stack-data->IPython->import_ipynb) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\user\anaconda3\envs\ml\lib\site-packages (from stack-data->IPython->import_ipynb) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\user\anaconda3\envs\ml\lib\site-packages (from stack-data->IPython->import_ipynb) (2.0.5)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\user\anaconda3\envs\ml\lib\site-packages (from importlib-resources>=1.4.0->jsonschema>=2.6->nbformat->import_ipynb) (3.8.0)
# Requirement already satisfied: six in c:\users\user\anaconda3\envs\ml\lib\site-packages (from asttokens->stack-data->IPython->import_ipynb) (1.16.0)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at monologg/kobert and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# importing Jupyter notebook from vision_main_final.ipynb
# importing Jupyter notebook from vision_model_final.ipynb
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# Requirement already satisfied: torchinfo in c:\users\user\anaconda3\envs\ml\lib\site-packages (1.7.1)
# Requirement already satisfied: keyboard in c:\users\user\anaconda3\envs\ml\lib\site-packages (0.13.5)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -mpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\users\user\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorboard (c:\users\user\anaconda3\envs\ml\lib\site-packages)

# %%
while True:
    sentence = input("하고싶은 말을 입력해주세요 : ")
    if sentence == "0":
        break
    predict = predict_sentence(sentence).squeeze().cpu().detach().numpy()
    cos_mean=predict_video(predict, sentence)
    print(cos_mean)
    print("\n")
# Out:
# 하고싶은 말을 입력해주세요 : 친구랑 약속이 있어서 기다리는데 아직 안 와.
# <string>:9: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at  C:\cb\pytorch_1000000000000\work\torch\csrc\utils\tensor_new.cpp:204.)
# <string>:20: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# <string>:100: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.41018778
#
#
# 하고싶은 말을 입력해주세요 : 회사 동료 언니들과 동생들이 있어. 많은 도움이 되지. 위로하면서.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.018900322
#
#
# 하고싶은 말을 입력해주세요 : 친구가 아직도 안 오고 있어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.69149184
#
#
# 하고싶은 말을 입력해주세요 : 다들 바쁘다고 해. 내 얘기는 들어주지도 않아.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.26166552
#
#
# 하고싶은 말을 입력해주세요 : 아니 근데 말 안 들어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.21558444
#
#
# 하고싶은 말을 입력해주세요 : 약속이 있어서 친구 기다리고 있는데 아직 안왔어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.36923566
#
#
# 하고싶은 말을 입력해주세요 : 아니 연락도 안 받아. 더워 죽겠는데!
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.13626249
#
#
# 하고싶은 말을 입력해주세요 : 최근에 좀 더 심해진 것 같아.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.5599853
#
#
# 하고싶은 말을 입력해주세요 : 약속을 잡을 때마다 약속 시간에 매번 늦어!
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.70171446
#
#
# 하고싶은 말을 입력해주세요 : 친구랑 약속이 있어서 기다리는데 아직 안 와.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.72701734
#
#
# 하고싶은 말을 입력해주세요 : 다들 바쁘다고 해. 내 얘기는 들어주지도 않아.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.61957914
#
#
# 하고싶은 말을 입력해주세요 : 아니 근데 말 안 들어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.570437
#
#
# 하고싶은 말을 입력해주세요 : 약속이 있어서 친구 기다리고 있는데 아직 안왔어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.573279
#
#
# 하고싶은 말을 입력해주세요 : 아니 연락도 안 받아. 더워 죽겠는데!
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.44757497
#
#
# 하고싶은 말을 입력해주세요 : 아니 연락도 안 받아. 더워 죽겠는데!
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.49141207
#
#
# 하고싶은 말을 입력해주세요 : 최근에 좀 더 심해진 것 같아.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.65405416
#
#
# 하고싶은 말을 입력해주세요 : 이곳에 도착한지 벌써 한시간이나 지나고 있어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.4612436
#
#
# 하고싶은 말을 입력해주세요 : 이곳에 도착한지 벌써 한시간이나 지나고 있어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.75413126
#
#
# 하고싶은 말을 입력해주세요 : 도착하자마자 연락은 해 봤지 하지만 전화를 안 받아.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.40885213
#
#
# 하고싶은 말을 입력해주세요 : 도착하자마자 연락은 해 봤지 하지만 전화를 안 받아.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.40099004
#
#
# 하고싶은 말을 입력해주세요 : 으. 화장실에 누가 토하고 안 치웠어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.0017078856
#
#
# 하고싶은 말을 입력해주세요 : 화장실 누가 토 해 놨다!
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.00022921663
#
#
# 하고싶은 말을 입력해주세요 : 아직도 있어. 진짜 더럽다.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.000743137
#
#
# 하고싶은 말을 입력해주세요 : 아직도 있어. 진짜 더럽다.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 9.74622e-05
#
#
# 하고싶은 말을 입력해주세요 : 아직도 있어. 진짜 더럽다.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.014159685
#
#
# 하고싶은 말을 입력해주세요 : 너무 더러워.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.3619787
#
#
# 하고싶은 말을 입력해주세요 : 자꾸 생각 나서 물도 안 넘어간다.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.043501493
#
#
# 하고싶은 말을 입력해주세요 : 놀란 거보다, 너무 더러워.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.038888436
#
#
# 하고싶은 말을 입력해주세요 : 기숙사 화장실 엉망진창이야. 가지 마.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.001171696
#
#
# 하고싶은 말을 입력해주세요 : 그 더러운 것들이 아직도 그대로 남아있어. 정말 역겨워.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.10549443
#
#
# 하고싶은 말을 입력해주세요 : 지금도 그대로 있어. 너무 더럽고 냄새 나.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.0029243112
#
#
# 하고싶은 말을 입력해주세요 : 빨리 잊어버려야지. 정말 최악이야.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.001947495
#
#
# 하고싶은 말을 입력해주세요 : 어제 저녁에 진짜 무서웠어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.8874534
#
#
# 하고싶은 말을 입력해주세요 : 밥 먹는데 지진 났는거야!
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.6497607
#
#
# 하고싶은 말을 입력해주세요 : 다행히 다치진 않았는데 어제 갑자기 지진이 나더라고.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.46009585
#
#
# 하고싶은 말을 입력해주세요 : 지진 났어. 난 괜찮은데, 친구가 다쳤어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.85489243
#
#
# 하고싶은 말을 입력해주세요 : 다치진 않았는데, 어후, 가슴이 아직도 두근두근 거려.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.53874326
#
#
# 하고싶은 말을 입력해주세요 : 사람 많은 데 가는 게 좀 안 좋겠지?
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.99959034
#
#
# 하고싶은 말을 입력해주세요 : 진짜 무서웠어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.9999719
#
#
# 하고싶은 말을 입력해주세요 : 다치진 않았는데 좀 무섭더라.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.99624604
#
#
# 하고싶은 말을 입력해주세요 : 미루기 힘들어. 그래도 불안해.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.6872622
#
#
# 하고싶은 말을 입력해주세요 : 미룰 수는 있는데, 나중에 더 위험해지면 어떡해?
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.70884335
#
#
# 하고싶은 말을 입력해주세요 : 다행히 다치진 않았는데 어제 갑자기 지진이 나더라고.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.9681692
#
#
# 하고싶은 말을 입력해주세요 : 다치진 않았는데, 어후, 가슴이 아직도 두근두근 거려.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.998398
#
#
# 하고싶은 말을 입력해주세요 : 지금 노트북을 꼼꼼히 살펴봤는데 이상이 하나도 없어. 작동도 너무나 잘 돼.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.7974903
#
#
# 하고싶은 말을 입력해주세요 : 나 축하해줘. 좋은 일이 있어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.70280135
#
#
# 하고싶은 말을 입력해주세요 : 당첨자는 한 명 뽑는 거였는데 내가 당첨됐어. 너무 운이 좋은 것 같아.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.684777
#
#
# 하고싶은 말을 입력해주세요 : 10km 마라톤 대회에 출전해서 내가 이전 기록을 훨씬 갱신했어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.7529757
#
#
# 하고싶은 말을 입력해주세요 : 정말 너무 좋았어. 내가 이렇게까지 잘 달릴 줄 몰랐어. 최선의 노력인 것 같아.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.6843366
#
#
# 하고싶은 말을 입력해주세요 : 드디어 구매한 노트북이 도착했어. 뜯어봐야지!
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.7197411
#
#
# 하고싶은 말을 입력해주세요 : 나 드디어 프로젝트가 끝났어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.9337793
#
#
# 하고싶은 말을 입력해주세요 : 어 너무너무 마음에 들어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.5809744
#
#
# 하고싶은 말을 입력해주세요 : 어 너무너무 마음에 들어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.7462052
#
#
# 하고싶은 말을 입력해주세요 : 내가 너무나 좋아하는 인플루언서가 진행하는 이벤트가 있었는데 거기에 당첨됐어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.80504924
#
#
# 하고싶은 말을 입력해주세요 : 그거 너무 좋겠다.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.8092651
#
#
# 하고싶은 말을 입력해주세요 : 내일 친구랑 약속 있는데 뭘 먹어야될지 잘 모르겠어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.7725777
#
#
# 하고싶은 말을 입력해주세요 : 나 오늘 짭새가 몰려있길래 궁금해서 구경 다녀 왔어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.73453075
#
#
# 하고싶은 말을 입력해주세요 : 강남역 주변에서 만나기로 했어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.7875986
#
#
# 하고싶은 말을 입력해주세요 : 둘 다 알려줘. 상의해보고 고를게.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.9945763
#
#
# 하고싶은 말을 입력해주세요 : 내일 비 소식이 있어? 오늘 그렇게 덥던데 비가 오려고 그랬나보네. 집에 우산이 있어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.97899055
#
#
# 하고싶은 말을 입력해주세요 : 정확하지는 않은데 어떤 사람이 말하는데.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.95307744
#
#
# 하고싶은 말을 입력해주세요 : 응. 모르겠어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.8219641
#
#
# 하고싶은 말을 입력해주세요 : 알았어. 앞으로 조심할게. 왜 몰려있었던지는 잘 모르겠어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.824817
#
#
# 하고싶은 말을 입력해주세요 : 우산이 있는데 비 맞을 일은 없어. 건강도 괜찮아, 아직은.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.32313374
#
#
# 하고싶은 말을 입력해주세요 : 우산이 있는데 비 맞을 일은 없어. 건강도 괜찮아, 아직은.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.44370466
#
#
# 하고싶은 말을 입력해주세요 : 일하는 거 지루해.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.9402492
#
#
# 하고싶은 말을 입력해주세요 : 우산이 있는데 비 맞을 일은 없어. 건강도 괜찮아, 아직은.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.9889255
#
#
# 하고싶은 말을 입력해주세요 : 나 요즘 허리가 아픈 것 같아.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.3925376
#
#
# 하고싶은 말을 입력해주세요 : 이번 시즌 마지막 준비였는데 실패했어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.74201584
#
#
# 하고싶은 말을 입력해주세요 : 이번이 마지막 회사였어. 더이상 준비할 것도 없어 이젠.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.8360829
#
#
# 하고싶은 말을 입력해주세요 : 집에서도 기대를 하고 있기 때문에 얘기를 못 하겠어 아니 슬퍼하실 거야.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.87349457
#
#
# 하고싶은 말을 입력해주세요 : 면접에 떨어졌다는 소식을 듣고 마음이 심란해서 길거리를 돌아다니고 있어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.47049463
#
#
# 하고싶은 말을 입력해주세요 : 면접에 떨어졌다는 소식을 듣고 마음이 심란해서 길거리를 돌아다니고 있어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.6748108
#
#
# 하고싶은 말을 입력해주세요 : 나 결국 헤어졌어.
# <string>:146: RuntimeWarning: Mean of empty slice.
# C:\Users\user\anaconda3\envs\ml\lib\site-packages\numpy\core\_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# nan
#
#
# 하고싶은 말을 입력해주세요 : 나 결국 헤어졌어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.9612264
#
#
# 하고싶은 말을 입력해주세요 : 부모님께서 지금 내 전화만 기다리고 계시겠지 어떻게 말씀드려야 될지 모르겠어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.9351904
#
#
# 하고싶은 말을 입력해주세요 : 권태기가 왔다고 그만 만나자 하더라.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.7351788
#
#
# 하고싶은 말을 입력해주세요 : 난 잘하는 게 없나봐.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.849569
#
#
# 하고싶은 말을 입력해주세요 : 해피가 어제 세상을 떠났어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.7612568
#
#
# 하고싶은 말을 입력해주세요 : 면접에 떨어졌다는 소식을 듣고 마음이 심란해서 길거리를 돌아다니고 있어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.9008462
#
#
# 하고싶은 말을 입력해주세요 : 나 요즘 허리가 아픈 것 같아.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.40409938
#
#
# 하고싶은 말을 입력해주세요 : 나 요즘 허리가 아픈 것 같아.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.84767693
#
#
# 하고싶은 말을 입력해주세요 : 나 아까 해피 산책시키다가 정말 깜짝 놀랬어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.30509856
#
#
# 하고싶은 말을 입력해주세요 : 나 어제 자다가 정말 깜짝 놀랐어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.104718484
#
#
# 하고싶은 말을 입력해주세요 : 네. 근데 달려와가지고 엄청 놀랐어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.5900217
#
#
# 하고싶은 말을 입력해주세요 : 다행히 빨리 잡아서 큰일은 없었어. 그래도 너무 놀랐어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.152525
#
#
# 하고싶은 말을 입력해주세요 : 해피 목줄이 끊어져버린거야!
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.2545895
#
#
# 하고싶은 말을 입력해주세요 : 잠결에 들어서 그런가 폭탄 터지는 소리가 들리더라고.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.39079988
#
#
# 하고싶은 말을 입력해주세요 : 잠을 자고 있는데 갑자기 천둥 소리가 나서 깜짝 놀라서 깼어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.23522665
#
#
# 하고싶은 말을 입력해주세요 : 너무 놀랐는데 오늘은 좀 나아졌어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.38886842
#
#
# 하고싶은 말을 입력해주세요 : 주변에 사람이 있지는 않았어 다행이지.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.5082951
#
#
# 하고싶은 말을 입력해주세요 : 지금도 진정이 안 돼. 얼마나 놀랬는지. 다음엔 진짜 조심해야겠어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.29358718
#
#
# 하고싶은 말을 입력해주세요 : 나 어제 자다가 정말 깜짝 놀랐어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.40668938
#
#
# 하고싶은 말을 입력해주세요 : 다행히 빨리 잡아서 큰일은 없었어. 그래도 너무 놀랐어.
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# start
# 0.4308469
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 while True:
# ----> 2     sentence = input("하고싶은 말을 입력해주세요 : ")
#       3     if sentence == "0":
#       4         break
#
# File ~\anaconda3\envs\ml\lib\site-packages\ipykernel\kernelbase.py:1075, in Kernel.raw_input(self, prompt)
#    1071 if not self._allow_stdin:
#    1072     raise StdinNotImplementedError(
#    1073         "raw_input was called, but this frontend does not support input requests."
#    1074     )
# -> 1075 return self._input_request(
#    1076     str(prompt),
#    1077     self._parent_ident["shell"],
#    1078     self.get_parent("shell"),
#    1079     password=False,
#    1080 )
#
# File ~\anaconda3\envs\ml\lib\site-packages\ipykernel\kernelbase.py:1120, in Kernel._input_request(self, prompt, ident, parent, password)
#    1117             break
#    1118 except KeyboardInterrupt:
#    1119     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1120     raise KeyboardInterrupt("Interrupted by user") from None
#    1121 except Exception:
#    1122     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
